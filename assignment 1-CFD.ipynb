# %%
#************************* PESHAWAR CAMPUS *************************************
import requests 
from bs4 import BeautifulSoup 
import pandas as pd

# %%
# scrapper for lahore campus
URL_Chiniot="https://cfd.nu.edu.pk/all-departments/"
r_Chiniot = requests.get(URL_Chiniot)
print (r_Chiniot)
# Out:
# <Response [200]>

# %%
soupChiniot = BeautifulSoup(r_Chiniot.content, 'html.parser')
print(soupChiniot.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    All Departments – FAST NUCES | CFD
#   </title>
#   <meta content="max-image-preview:large" name="robots">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch">
#     <link href="//s.w.org" rel="dns-prefetch"/>
#     <link href="https://cfd.nu.edu.pk/feed/" rel="alternate" title="FAST NUCES | CFD » Feed" type="application/rss+xml"/>
#     <link href="https://cfd.nu.edu.pk/comments/feed/" rel="alternate" title="FAST NUCES | CFD » Comments Feed" type="application/rss+xml"/>
#     <script type="text/javascript">
# ...

# %%
Id = []
Name = []
Designation = []
HEC_Approved = []
Highest_Education = []
Email = []
Department = []
Extension = []
ImageUrl = []

# %%
# getting the departments links as well as the Departments
links = []
Depts = soupChiniot.find('div',class_='kc-elm kc-css-633007 kc_row kc_row_inner')
Anchors = Depts.findAll('a')
for i in range(len(Anchors)):
    a = Anchors[i]
    links.append(a['href'])

# %%
for i in range(len(links)):
    Chiniot_URL = links[i]
    r_chiniot_request = requests.get(Chiniot_URL)
    print(r_chiniot_request)
#     soupChiniotCS = BeautifulSoup(r_chiniot_request.content,'html.parser')

# %%
ChiniotSE_URL = 'https://cfd.nu.edu.pk/department-se'
r_chiniot_request_SE = requests.get(ChiniotSE_URL)
print(r_chiniot_request_SE)

# %%
soupChiniotSE = BeautifulSoup(r_chiniot_request_SE.content,'html.parser')
print(soupChiniotSE.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Temporary Page
#   </title>
#   <link href="https://cf.wpx.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet"/>
#   <style>
#    body {
#             color: #fff;
#             background: linear-gradient(-45deg,#fc5819, #961251);
#         }
#
#         h1,
#         h6 {
#             font-family: 'Montserrat', sans-serif;
#             font-weight: 300;
#             font-size: 1.60rem;
#             text-align: center;
#             position: absolute;
#             right: 0;
#             left: 0;
#             padding-left: 50px;
#             padding-right: 50px;
#         }
#         a {
#             color: #fff;
#             text-align: center;
#         }
#
#             a:hover {
#                 color:#961251;
#             }
#
#         .button {
# ...

# %%
ChiniotEE_URL = 'https://cfd.nu.edu.pk/department-ee'
r_chiniot_request_EE = requests.get(ChiniotEE_URL)
print(r_chiniot_request_EE)

ChiniotSH_URL = 'https://cfd.nu.edu.pk/department-sh'
r_chiniot_request_SH = requests.get(ChiniotSH_URL)
print(r_chiniot_request_SH)

ChiniotFSM_URL = 'https://cfd.nu.edu.pk/department-fsm'
r_chiniot_request_FSM = requests.get(ChiniotFSM_URL)
print(r_chiniot_request_FSM)
# Out:
# <Response [403]>
# <Response [403]>
# <Response [403]>

# %%
ChiniotCS_URL = 'https://cfd.nu.edu.pk/department-cs'
# r_chiniot_request_CS = requests.get(ChiniotCS_URL)
# print(r_chiniot_request_CS)
soupChiniotCS = BeautifulSoup(r_chiniot_request_CS.content,'html.parser')
print(soupChiniotCS.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    FAST School of Computing – FAST NUCES | CFD
#   </title>
#   <meta content="max-image-preview:large" name="robots">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch">
#     <link href="//s.w.org" rel="dns-prefetch"/>
#     <link href="https://cfd.nu.edu.pk/feed/" rel="alternate" title="FAST NUCES | CFD » Feed" type="application/rss+xml"/>
#     <link href="https://cfd.nu.edu.pk/comments/feed/" rel="alternate" title="FAST NUCES | CFD » Comments Feed" type="application/rss+xml"/>
#     <script type="text/javascript">
# ...

# %%
names = soupChiniotCS.findAll('div',class_='unitech-teacher__inner')
for i in range(len(names)):
    Name.append(names[i].h4.text.split('\n')[0].strip())

# %%
# print(Name.clear())
print(len(Name))
print(Name)
# Out:
# 49
# ...

# %%
# getting the departments links as well as the Departments
Depts = soupChiniot.findAll('div',class_='content-desc')
# print(links[0])
for i in range(len(Depts)):
    l = Depts[i]
    print(Depts[i].text)
# Out:
# Department of Computer Science
#
# Department of Software Engineering
#
# Department of Electrical Engineering
#
# Department of Sciences & Humanities
#
# FAST School of Management

# %%
IDS = soupChiniotCS.findAll('div',class_='unitech-teacher__inner')

for i in range(len(names)):
    Id.append(IDS[i].h4.a['href'].split('/')[-2])

# %%
# print(Id.clear())
print(Id)
print(len(Id))
# Out:
# ['muhammad-ahmad', 'muhammad-shahzad-sarfraz', 'anwar-shah', 'bilal-khan', 'hashim-yasin', 'muhammad-fayyaz', 'muhammad-umar-aftab', 'muhammad-usama', 'rabia-maqsood', 'adeel-ashraf-cheema', 'asma-sattar', 'hafiz-tayyeb-javed', 'maria-maqsood', 'muhammad-atif', 'rida-ghafoor-hussain', 'rizwan-ul-haq', 'zain-iqbal', 'abdul-qadeer-bilal', 'ali-hamza', 'ali-raza', 'aliza-saeed', 'aqsa-younas', 'asif-ameer', 'ayesha-liaqat', 'faryal-saud', 'haseeb-arshad', 'khalid-hussain', 'mahzaib-younas', 'masood-habib', 'mazhar-hussain', 'mughees-ismail', 'muhammad-adeel', 'muhammad-hannan-farooq', 'muhammad-shahbaz-ayyaz', 'muhammad-suffian', 'muhammad-usman-joyia', 'muhammad-yousaf', 'muiz-qadir', 'nasreen-akhtar', 'saba-aslam', 'saba-ghani', '507221', 'saqib-hayat', 'sumaira-mustafa', 'usman-ghous', 'areeba-waseem', 'kashaf-shakoor', 'momna-javaid', 'rana-mobeen-tariq']
# 49

# %%
# 3- Getting the Designation (string)
DES = soupChiniotCS.findAll('div',class_='unitech-teacher__inner')
for i in range(len(names)):
    Designation.append(str(DES[i].h6.text))

# %%
# print(Designation.clear())
print(Designation)
print(len(Designation))
# Out:
# ['Associate Professor & HOD', 'Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Assistant Professor', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Lecturer', 'Instructor', 'Instructor', 'Instructor', 'Instructor']
# 49

# %%
# 3- Getting the Email (string)
EM = soupChiniotCS.findAll('ul',class_='unitech-teacher-social-icon')
# print(EM)
for i in range(len(names)):
    Email.append(EM[i].p.text)

# %%
# print(Email.clear())
print(Email)
print(len(Email))
# Out:
# ['dr.ahmad@nu.edu.pk', 'shahzad.sarfraz@nu.edu.pk', 'Anwar.Shah@nu.edu.pk', 'khan.bilal@nu.edu.pk', 'hashim.yasin@nu.edu.pk', 'm.fayyaz@nu.edu.pk', 'umar.aftab@nu.edu.pk', 'm.usama@nu.edu.pk', 'rabia.maqsood@nu.edu.pk', 'adeel.cheema@nu.edu.pk', 'asma.sattar@nu.edu.pk', 'tayyeb.javed@nu.edu.pk', 'maria.maqsood@nu.edu.pk', 'atif.muhammad@nu.edu.pk', 'rida.ghafoor@nu.edu.pk', 'rizwan.haq@nu.edu.pk', 'zain.iqbal@nu.edu.pk', 'a.qadeer@nu.edu.pk', 'ali.Hamza@nu.edu.pk', 'aliraza@nu.edu.pk', 'aliza.saeed@nu.edu.pk', 'aqsa.younas@nu.edu.pk', 'asif.ameer@nu.edu.pk', 'ayesha.liaqat@nu.edu.pk', 'faryal.saud@nu.edu.pk', 'haseeb.arshad@nu.edu.pk', 'khalid.hussain@nu.edu.pk', 'mahzaib.Younas@nu.edu.pk', 'm.habib@nu.edu.pk', 'mazhar.h@nu.edu.pk', 'mughees.ismail@nu.edu.pk', 'm.adeel@nu.edu.pk', 'hannan.farooq@nu.edu.pk', 'Shahbaz.Ayyaz@nu.edu.pk', 'm.suffian@nu.edu.pk', 'usman.joyia@nu.edu.pk', 'muhammad.yousaf@nu.edu.pk', 'muiz.qadir@nu.edu.pk', 'nasreen.akhtar@nu.edu.pk', 'saba.aslam@nu.edu.pk',
# ...

# %%
# 9- getting the ImageURL (URL)
IMG = soupChiniotCS.findAll('div',class_='unitech-teacher__thumb')

for i in range(len(names)):
    ImageUrl.append(IMG[i].img['src'])

# %%
# print(ImageUrl.clear())
print(ImageUrl)
print(len(ImageUrl))
# Out:
# ['https://cfd.nu.edu.pk/wp-content/uploads/2020/09/5995-e1678167524734-235x300.png', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/IMG_3159-removebg-preview-e1689144760508-235x300.png', 'https://cfd.nu.edu.pk/wp-content/uploads/2022/08/IMG_1381-scaled-e1660974348817-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/Dr.-Bilal-Khan-scaled-e1690185321734-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/hashim-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2022/01/12345-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2020/09/5994-1-e1678168158795-235x300.png', 'https://cfd.nu.edu.pk/wp-content/uploads/2022/08/Dr-Usama-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/Dr.-Rabia-Maqsood-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/adeel-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2019/09/asra-235x300.jpg', 'https://cfd.nu.edu.pk/wp-content/uploads/2020/03/Mr.-Hafiz-Tayyab-Javed-Assistant-Professo
# ...

# %%
# 4- getting the HEC Approved PhD Supervisor (bool)  
HEC = soupChiniotCS.findAll('ul',class_='unitech-teacher-social-icon')
for i in range(len(names)):
    try:
        HEC_Approved.append(HEC[i].find('p',class_='hec').text.strip())
    except:
        HEC_Approved.append('N/A')

# %%
# print(HEC_Approved.clear())
print(HEC_Approved)
print(len(HEC_Approved))
# Out:
# ['HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'HEC approved PhD Supervisor', 'N/A', 'HEC approved PhD Supervisor', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A']
# 49

# %%
#    5- Getting the Highest Education (string)
# Out:
# 22
# 13
# 6

# %%
# # print(Highest_Education.clear())   
# print(Highest_Education)
# print(len(Highest_Education))

# %%
# 7- getting the Department (string)

ArrayOfDepartments = []
dept = soupPeshawarCS.findAll('ul',class_='dropdown')
print(dept.a)
# getting the no of departments and store in the list

# lengthOf = len(soupPeshawarCS.find('ul',class_='dropdown'))
# for i in range(lengthOf):
#     ArrayOfDepartments.append(Dept.find('div',class_='text-center white').findAll('a')[i].text)
# print(ArrayOfDepartments)

# # print(Department.clear())
# print(len(Department))
# print(Department)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # 7- getting the Department (string)
#       3 ArrayOfDepartments = []
# ----> 4 dept = soupPeshawarCS.findAll('ul',class_='dropdown')
#       5 print(dept.a)
#
# NameError: name 'soupPeshawarCS' is not defined

# %%
# 8- getting the Extension (integer)
EXT_url = "https://cfd.nu.edu.pk/faculty/"+Id[0]+"/"
req = requests.get(EXT_url)
soupEXT = BeautifulSoup(req.content, 'html.parser')
print(req)
# print(soupEXT)
# Out:
# <Response [403]>

# %%
# Extension.clear()
print(len(Extension))
print(Extension)
# Out:
# 0
# []
